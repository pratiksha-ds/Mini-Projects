# %% [markdown]
# # ITP Mini Project
# Courier Management System
# For a seamless eCommerce shopping experience, it is essential to deliver the product promptly to the customer. And that’s where a professional courier service plays a vital role. 'FastTrack' courier company stores the relevant data of its clients and parcels in the form of dictionary. Create a dictionary for storing shipment information in key-value pairs. Shipment id is used as a key and list of other attributes like sender, receiver, start date, Delivery Date, Sender_location, Receiver_location, Delivery status, Shipping cost is associated with shipment id. Use the data shown in the table below.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# Use below table to refer to client’s data. Please note that a client can be a sender or receiver.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ### Q1. Create a Dictionary of lists to store the information of shipments given in the table

# %%
ShipmentInfo = {
    '101':{'sender':'1','receiver':'3','start_date':2020-3-14,'delivery_date':2020-3-25,'sender_location':'Area1','reciever_location' : 'Area6','delivery_status':'delivered','shipping_cost':'198'},
    '102':{'sender':'4','receiver':'1','start_date':2020-6-18,'delivery_date':2020-7-9,'sender_location':'Area2','reciever_location' : 'Area4','delivery_status':'delivered','shipping_cost':'275'},
    '103':{'sender':'2','receiver':'3','start_date':2020-12-1,'delivery_date':'Null','sender_location':'Area5','reciever_location' : 'Area1','delivery_status':'InTransit','shipping_cost':'200'},
    '104':{'sender':'1','receiver':'5','start_date':2020-6-23,'delivery_date':2020-6-25,'sender_location':'Area1','reciever_location' : 'Area4','delivery_status':'delivered','shipping_cost':'314'},
    '105':{'sender':'3','receiver':'4','start_date':2020-8-29,'delivery_date':2020-9-10,'sender_location':'Area5','reciever_location' : 'Area3','delivery_status':'delivered','shipping_cost':'275'},
    '106':{'sender':'6','receiver':'2','start_date':2020-6-28,'delivery_date':'Null','sender_location':'Area3','reciever_location' : 'Area1','delivery_status':'InTransit','shipping_cost':'270'}
}
ShipmentInfo
# Out:
# {'101': {'sender': '1',
#   'receiver': '3',
#   'start_date': 2003,
#   'delivery_date': 1992,
#   'sender_location': 'Area1',
#   'reciever_location': 'Area6',
#   'delivery_status': 'delivered',
#   'shipping_cost': '198'},
#  '102': {'sender': '4',
#   'receiver': '1',
#   'start_date': 1996,
#   'delivery_date': 2004,
#   'sender_location': 'Area2',
#   'reciever_location': 'Area4',
#   'delivery_status': 'delivered',
#   'shipping_cost': '275'},
#  '103': {'sender': '2',
#   'receiver': '3',
#   'start_date': 2007,
#   'delivery_date': 'Null',
#   'sender_location': 'Area5',
#   'reciever_location': 'Area1',
#   'delivery_status': 'InTransit',
#   'shipping_cost': '200'},
#  '104': {'sender': '1',
#   'receiver': '5',
#   'start_date': 1991,
#   'delivery_date': 1989,
#   'sender_location': 'Area1',
#   'reciever_location': 'Area4',
#   'delivery_status': 'delivered',
#   'shipping_cost': '314'},
#  '105': {'sender': '3',
#   'receiver': '4',
#   'start_date': 1983,
# ...

# %% [markdown]
# ### Q2. Create a Dictionary of to store the information of clients given in the table.

# %%
client_data= {'1':'Phillip','2':'Omega III','3':'Ramya','4':'Romesh','5':'John'}
print(client_data)
# Out:
# {'1': 'Phillip', '2': 'Omega III', '3': 'Ramya', '4': 'Romesh', '5': 'John'}

# %% [markdown]
# ### Q3. Write a code to replace client’s id with their respective name in shipment dictionary using a loop and dictionary comprehension

# %% [markdown]
# 1. start
# 2. create a empty dictionary, empty{}
# 3. for key,value in ShipmentInfo.items():
# 4.new = {i:client_data[j] if i in ('sender','receiver') else j for i,j in value.items()}
# 5. empty[key]=new
# 5. print:empty

# %% [markdown]
# ### Q.4 Print all shipment details that are sent by Phillip

# %% [markdown]
# 1. start
# 2. p = list(map(filter(lambda x:x['sender']=='Phillip',empty.values()),ShipmentInfo.values())
# 3. print p
# 4. end

# %% [markdown]
# ### Q5. Print all shipment details that are received by Ramya

# %% [markdown]
# 1. start
# 2.list(map(filter (lambda value:value['reciever']=='ramya',ShipmentInfo.values),ShipmentInfo.values()))
# 3.print(r)
# 4.end

# %% [markdown]
# ### Q6. Print all shipments which are in 'In-Transit' status

# %% [markdown]
# 1.start
# 2.intrans = list(map(filter(lambda value:value['delivery_status']=='InTransit',ShipmentInfo.values()),ShipmentInfo.values()))
# 3. print:intrans
# 4. end

# %% [markdown]
# ### Q7. Print all shipments which are delivered within 7 days of courier Start date

# %% [markdown]
# 1. start
# 2. from datetime import date
# 3. values of ShipmentInfo.items()
# 4. for value==('start_date','delivery_date')
# 5. a = filter((delivery_date - startdate)<7)
# 6.print(list(a))
# 7. end

# %% [markdown]
# ### Q8. Print all shipments which are delivered after 15 days of courier start date or not yet been delivered.

# %% [markdown]
# 1. start
# 2. from dataetime import date
# 3. values of ShipmentInfo.items()
# 4.for value==(start_date,delivery_date)
# 5. b = filter((delivery_date - startdate)>15) and value['delivery_status']=='InTransit'
# 6. print(list(b))
# 7. end

# %% [markdown]
# ### Q 9. Write a function find_all_routes to display all possible routes from senders location to receivers location given in the dictionary for each shipment.¶

# %% [markdown]
# Graph data structure is used to represent network of pickup and delivery nodes. Consider a below graph diagram for given nodes in the table where sender location and receiver location is represented by node with number.
# Connection between two nodes shows route exists between those areas. E.g there exists a path from area 1 to area 2 but there is no direct route between area1 and area5. please note that this routes are bidirectional.
# To reach to area5 from area1 , delivery person can take any route like 1-2-4-5 or 1-2-3-4-5

# %% [markdown]
# #![image.png](attachment:image.png)

# %% [markdown]
# Any graph like the one shown above can be represented by matrix shown below. presence of 1 represents the route between nodes and 0 represents there is no direct route exist between the nodes. Create matrix for the network shown above and using this matrix find all possible routes from A to B.

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# 1. start
# 2. save every cell as a node with rows n columns
# 3.start breadth first search
# 4. mark visited cell as 1(True) and 0 for False
# 5. update the distance when reached destination
# 6.return distace from source to detination
# 7. end
